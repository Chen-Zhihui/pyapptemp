# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("./match_count_history.csv")
data.head()
# Out:
#    c  count
# 0  1  10240
# 1  2   7556
# 2  3   4544
# 3  4   3474
# 4  5   2530

# %%
sns.set_theme(style="ticks")
sns.lmplot(x="c", y="count", data=data)

# %%
plt.plot(data["c"].values, data["count"].values)

# %%
y
# Out:
# <bound method DataFrame.count of        c  count
# 0      1  10240
# 1      2   7556
# 2      3   4544
# 3      4   3474
# 4      5   2530
# ..   ...    ...
# 216  363      1
# 217  369      1
# 218  373      1
# 219  394      1
# 220  417      1
#
# [221 rows x 2 columns]>
